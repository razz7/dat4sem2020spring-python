# %%
import pandas as pd

# %%
url = 'https://api.statbank.dk/v1/tables'
file_name = '/home/tha/documents/sem4/python/2020s/folk1A.csv'
dst = pd.read_json(url)
#dst.to_csv(file_name, encoding='utf-8', index=False)
dst[:20]
# Out:
#           id                                               text   unit  \
# 0     FOLK1A                        Folketal den 1. i kvartalet  antal
# 1     FOLK1B                        Folketal den 1. i kvartalet  antal
# 2     FOLK1C                        Folketal den 1. i kvartalet  antal
# 3     FOLK1D                        Folketal den 1. i kvartalet  antal
# 4     FOLK1E                        Folketal den 1. i kvartalet  antal
# 5      FOLK2                                 Folketal 1. januar  antal
# 6      FOLK3                                 Folketal 1. januar  antal
# 7         FT       Folketal (summariske tal fra folketællinger)  antal
# 8      BEF5F  Personer født på Færøerne og bosat i Danmark 1...  antal
# 9      BEF5G  Personer født i Grønland og bosat i Danmark 1....  antal
# 10      BEF5                             Folketal pr. 1. januar  antal
# 11       BY3                                 Folketal 1. januar      -
# 12       BY1                                 Folketal 1. januar  antal
# 13       BY2                                 Folketal 1. januar  antal
# 14      BEF4                                 Folketal 1. januar  antal
# 15     HISB3                           Nøgletal om befolkningen  antal
# 16     BEV22      Befolkningens udvikling (foreløbig opgørelse)  antal
# 17    BEV107                            Befolkningens udvikling  antal
# 18    GALDER                                   Gennemsnitsalder   gns.
# 19  KMGALDER                                   Gennemsnitsalder   gns.
#
#                 updated firstPeriod latestPeriod  active  \
# 0   2019-11-08T08:00:00      2008K1       2019K4    True
# 1   2019-11-08T08:00:00      2008K1       2019K4    True
# 2   2019-11-08T08:00:00      2008K1       2019K4    True
# 3   2019-11-08T08:00:00      2008K1       2019K4    True
# 4   2019-11-08T08:00:00      2008K1       2019K4    True
# 5   2019-02-11T08:00:00        1980         2019    True
# 6   2019-02-11T08:00:00        2008         2019    True
# 7   2019-02-11T08:00:00        1769         2019    True
# 8   2019-02-11T08:00:00        2008         2019    True
# 9   2019-02-11T08:00:00        2008         2019    True
# 10  2019-02-11T08:00:00        1990         2019    True
# 11  2019-04-30T08:00:00        2017         2019    True
# 12  2019-04-30T08:00:00        2010         2019    True
# 13  2019-04-30T08:00:00        2010         2019    True
# 14  2019-04-01T08:00:00        1901         2019    True
# 15  2019-02-14T08:00:00        1901         2019    True
# 16  2019-11-08T08:00:00      2007K2       2019K3    True
# 17  2019-02-11T08:00:00        2006         2018    True
# 18  2019-02-11T08:00:00        2005         2019    True
# 19  2019-02-28T08:00:00        2007         2019    True
#
#                                             variables
# 0               [område, køn, alder, civilstand, tid]
# 1          [område, køn, alder, statsborgerskab, tid]
# 2   [område, køn, alder, herkomst, oprindelsesland...
# 3          [område, køn, alder, statsborgerskab, tid]
# 4                 [område, køn, alder, herkomst, tid]
# 5   [alder, køn, herkomst, statsborgerskab, oprind...
# 6          [fødselsdag, fødselsmåned, fødselsår, tid]
# 7                               [hovedlandsdele, tid]
# 8             [køn, alder, forældrenes fødested, tid]
# 9             [køn, alder, forældrenes fødested, tid]
# 10                        [køn, alder, fødeland, tid]
# 11  [byområder og landdistrikter, folketal, areal ...
# 12     [byområder og landdistrikter, alder, køn, tid]
# 13            [kommune, bystørrelse, alder, køn, tid]
# 14                                         [øer, tid]
# 15                               [bevægelsesart, tid]
# 16                  [område, bevægelsesart, køn, tid]
# 17                  [område, bevægelsesart, køn, tid]
# 18                                [kommune, køn, tid]
# 19                                   [sogn, køn, tid]

# %%
url = '/home/tha/documents/sem4/python/2020s/FOLK1A.json'
folk1A = pd.read_json(url,orient='values')
folk1A
# Out:
#                                                      dataset
# dimension  {'OMRÅDE': {'label': 'region', 'category': {'i...
# label      Population at the first day of the quarter by ...
# source                                    Statistics Denmark
# updated                                 2019-11-08T07:00:00Z
# value      [5827463, 2845453, 2149938, 288226, 543846, 61...

# %%
#with open('/home/tha/documents/sem4/python/2020s/FOLK1A.json') as json_file:
#    data = json.load(json_file)
#
#print(data)

# %%
# first make sure jsonstat.py is installed: `pip install jsonstat.py`
import jsonstat
#url = 'http://json-stat.org/samples/oecd-canada.json'
url = 'https://api.statbank.dk/v1/data/FOLK1A/JSONSTAT?lang=en&valuePresentation=CodeAndValue&OMR%C3%85DE=000&K%C3%98N=TOT&ALDER=IALT&CIVILSTAND=*'
collection = jsonstat.from_url(url)

# print list of dataset contained into the collection
print(collection)

# select the first dataset of the collection and print a short description
ds = collection.dataset(0)
print(ds)
# Out:
# JsonstatCollection contains the following JsonStatDataSet:
# +-----+-----------+
# | pos | dataset   |
# +-----+-----------+
# | 0   | 'dataset' |
# +-----+-----------+
# name:   'dataset'
# label:  'Population at the first day of the quarter by region, sex, age, marital status, Indhold and time'
# source: 'Population at the first day of the quarter by region, sex, age, marital status, Indhold and time'
# size: 5
# +-----+--------------+----------------+------+--------+
# | pos | id           | label          | size | role   |
# +-----+--------------+----------------+------+--------+
# | 0   | OMRÅDE       | region         | 1    | geo    |
# | 1   | KØN          | sex            | 1    |        |
# | 2   | ALDER        | age            | 1    |        |
# | 3   | CIVILSTAND   | marital status | 5    |        |
# | 4   | ContentsCode | Indhold        | 1    | metric |
# | 5   | Tid          | time           | 1    | time   |
# +-----+--------------+----------------+------+--------+

# %%
df = ds.to_data_frame()
marital = df[['marital status','Value']]
marital.columns = ['status','no']
print(marital)
marital.plot.bar(x='status',y='no',rot=0)
# Out:
#                 status       no
# 0            TOT Total  5827463
# 1      U Never married  2845453
# 2  G Married/separated  2149938
# 3            E Widowed   288226
# 4           F Divorced   543846

# %%
for d in oecd.dimensions():
    print(d)
# Out:
# +-----+-------+-------------------+
# | pos | idx   | label             |
# +-----+-------+-------------------+
# | 0   | '000' | '000 All Denmark' |
# +-----+-------+-------------------+
# +-----+-------+-------------+
# | pos | idx   | label       |
# +-----+-------+-------------+
# | 0   | 'TOT' | 'TOT Total' |
# +-----+-------+-------------+
# +-----+--------+--------------+
# | pos | idx    | label        |
# +-----+--------+--------------+
# | 0   | 'IALT' | 'IALT Total' |
# +-----+--------+--------------+
# +-----+-------+-----------------------+
# | pos | idx   | label                 |
# +-----+-------+-----------------------+
# | 0   | 'TOT' | 'TOT Total'           |
# | 1   | 'U'   | 'U Never married'     |
# | 2   | 'G'   | 'G Married/separated' |
# | 3   | 'E'   | 'E Widowed'           |
# | 4   | 'F'   | 'F Divorced'          |
# +-----+-------+-----------------------+
# +-----+----------+-----------------------------------------------------+
# | pos | idx      | label                                               |
# +-----+----------+-----------------------------------------------------+
# | 0   | 'FOLK1A' | 'FOLK1A Population at the first day of the quarter' |
# +-----+----------+-----------------------------------------------------+
# +-----+----------+-----------------+
# | pos | idx      | label           |
# +-----+----------+-----------------+
# | 0   | '2019K4' | '2019K4 2019Q4' |
# +-----+----------+-----------------+
